# %% [markdown]
# # Exploratory Data Analysis: Nigeria
#
# This notebook contains the exploratory data analysis for Nigeria.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ## 1. Load Data
# We load the raw data and display the first few rows.

# %%
data_path = os.path.join('..', 'data', 'nigeria.csv')
df = pd.read_csv(data_path)
df.head()

# %% [markdown]
# ## 2. Basic Statistics
# Summary statistics of the numerical variables.

# %%
df.describe()

# %% [markdown]
# ## 3. Missing Values
# Check for missing data.

# %%
df.isnull().sum()

# %% [markdown]
# ## 4. Temperature Trend over Time
# If 'Date' or 'YEAR'/'MO' exists, plot temperature over time.

# %%
if 'Date' in df.columns:
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)
elif 'YEAR' in df.columns and 'MO' in df.columns and 'DY' in df.columns:
    df['Date'] = pd.to_datetime(df[['YEAR', 'MO', 'DY']].rename(columns={'YEAR': 'year', 'MO': 'month', 'DY': 'day'}))
    df.set_index('Date', inplace=True)

if 'T2M' in df.columns:
    plt.figure(figsize=(12, 5))
    df['T2M'].plot()
    plt.title(f'{country.capitalize()} - Temperature (T2M) over time')
    plt.ylabel('Temperature (C)')
    plt.show()
